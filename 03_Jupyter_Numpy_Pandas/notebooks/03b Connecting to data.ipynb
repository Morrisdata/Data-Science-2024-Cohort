# %% [markdown]
# #### CONNECT TO DATA

# %% [markdown]
# It is a good practice but sometimes a luxary to review metadata or any documentation.
# At a minimum get the reference to the documentation and have them in a handy easy to get to location.
# Iterating on testing coding ideas, and becoming more familiar with the documentation will speed up the development process. For student projects Kaggle.com has excellent documentation and resources on all types of datasets.

# %% [markdown]
# WHO alcohol consumption data:
# - article: http://fivethirtyeight.com/datalab/dear-mona-followup-where-do-people-drink-the-most-beer-wine-and-spirits/
# - original data: https://github.com/fivethirtyeight/data/tree/master/alcohol-consumption
# - class file: drinks.csv (with additional 'continent' column)
#
# National UFO Reporting Center data:
# - main page: http://www.nuforc.org/webreports.html
# - file: ufo.csv

# %%
import pandas as pd

# %% [markdown]
# - reading files
# - https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html
# - read_csv()
#
# #### read_csv()

# %%
# read_csv()
drinks = pd.read_csv('C://Users//Matth//OneDrive//Desktop/DATA//drinks.csv')
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %%
# remove headers
drinks = pd.read_csv('C://Users//Matth//OneDrive//Desktop/DATA//drinks.csv', header = None)
drinks
# Out:
#                0              1                2              3  \
# 0        country  beer_servings  spirit_servings  wine_servings
# 1    Afghanistan              0                0              0
# 2        Albania             89              132             54
# 3        Algeria             25                0             14
# 4        Andorra            245              138            312
# ..           ...            ...              ...            ...
# 189    Venezuela            333              100              3
# 190      Vietnam            111                2              1
# 191        Yemen              6                0              0
# 192       Zambia             32               19              4
# 193     Zimbabwe             64               18              4
#
#                                 4          5
# 0    total_litres_of_pure_alcohol  continent
# 1                             0.0         AS
# 2                             4.9         EU
# ...

# %%
# rename headers
drinks = pd.read_csv('C://Users//Matth//OneDrive//Desktop/DATA//drinks.csv', 
                     header = None,
                    names = ["Country", "beer", "wine", "tot ltr alcohol", "continent"])
drinks
# Out:
#                    Country             beer           wine  \
# country      beer_servings  spirit_servings  wine_servings
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# ...                    ...              ...            ...
# Venezuela              333              100              3
# Vietnam                111                2              1
# Yemen                    6                0              0
# Zambia                  32               19              4
# Zimbabwe                64               18              4
#
#                           tot ltr alcohol  continent
# country      total_litres_of_pure_alcohol  continent
# Afghanistan                           0.0         AS
# Albania                               4.9         EU
# ...

# %%
# Choosing specific columns
drinks = pd.read_csv('C://Users//Matth//OneDrive//Desktop/DATA//drinks.csv', 
                     usecols =['country', 'beer_servings']  )
drinks
# Out:
#          country  beer_servings
# 0    Afghanistan              0
# 1        Albania             89
# 2        Algeria             25
# 3        Andorra            245
# 4         Angola            217
# ..           ...            ...
# 188    Venezuela            333
# 189      Vietnam            111
# 190        Yemen              6
# 191       Zambia             32
# 192     Zimbabwe             64
#
# [193 rows x 2 columns]

# %%
# making it more dynamic
source = 'C://Users//Matth//OneDrive//Desktop/DATA//drinks.csv'
cols = ['country', 'beer_servings']
drinks = pd.read_csv(source, usecols = cols)
drinks
# Out:
#          country  beer_servings
# 0    Afghanistan              0
# 1        Albania             89
# 2        Algeria             25
# 3        Andorra            245
# 4         Angola            217
# ..           ...            ...
# 188    Venezuela            333
# 189      Vietnam            111
# 190        Yemen              6
# 191       Zambia             32
# 192     Zimbabwe             64
#
# [193 rows x 2 columns]

# %%
# creating a path
'''
this is done using your os current path'''
# Out:
# '\nthis is done using your os current path'

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Matth\\OneDrive\\Desktop\\DATA'

# %%
#Change the current working directory
from pathlib import Path
path = Path('C://Users//Matth//OneDrive//Desktop/DATA//')
os.chdir(path)
os.getcwd()
# Out:
# 'C:\\Users\\Matth\\OneDrive\\Desktop\\DATA'

# %%
drinks = pd.read_table(path +'drinks.csv')
drinks
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 drinks = pd.read_table(path +'drinks.csv')
#       2 drinks
#
# TypeError: unsupported operand type(s) for +: 'WindowsPath' and 'str'

# %%
#Change the current working directory
from pathlib import Path
path = Path('C://Users//Matth//OneDrive//Desktop/DATA')
path = str(path)
os.chdir(path)
os.getcwd()
# Out:
# 'C:\\Users\\Matth\\OneDrive\\Desktop\\DATA'

# %%
drinks = pd.read_csv(path +'//drinks.csv')
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %%
If the csv was not formatted correctly or we want to read it in through the table method notice the difference

# %%
drinks = pd.read_table(path +'//drinks.csv')
drinks
# Out:
#     country,beer_servings,spirit_servings,wine_servings,total_litres_of_pure_alcohol,continent
# 0                             Afghanistan,0,0,0,0.0,AS
# 1                             Albania,89,132,54,4.9,EU
# 2                               Algeria,25,0,14,0.7,AF
# 3                          Andorra,245,138,312,12.4,EU
# 4                              Angola,217,57,45,5.9,AF
# ..                                                 ...
# 188                         Venezuela,333,100,3,7.7,SA
# 189                             Vietnam,111,2,1,2.0,AS
# 190                                 Yemen,6,0,0,0.1,AS
# 191                              Zambia,32,19,4,2.5,AF
# 192                            Zimbabwe,64,18,4,4.7,AF
#
# [193 rows x 1 columns]

# %%
This can be fixed using the sep parameter and putting in the correct delimiter

# %%
drinks = pd.read_table(path +'//drinks.csv', sep = ',')
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %% [markdown]
# ### Class Room Exercise
# - if you have not done so already, create a storage folder for your data.
# - store Chipolte data in this folder along with other data sets of interest
# - Set up a jupyter notebook and establish a connection using the entire path name to folder
# - once you have that completed
# - set up a path to folder using the shortcut method.
