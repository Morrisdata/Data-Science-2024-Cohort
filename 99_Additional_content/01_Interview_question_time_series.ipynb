# %% [markdown]
# # INTERVIEW QUESTION CONCERNED ABOUT CUSTOMER BEHAVIOR
# This unit assumes students are aware of many aspects of Times Series and leans into interview questions that a candidate ends up using Time Series as their answer.
# - We will begin with the first step into Time Series as a refresher.
# - We will then look at a basic interview line of questions.
# - Finally we will go into each question and review types of answers and follow up questions an interviewer may ask.

# %% [markdown]
# ## Basic Concept of Time Series

# %% [markdown]
# ## Basic interview line of questions
# - Problem statement
# - How would you ensure that you have the right data?
# - How would you validate the model?
# - What might you do to improve results?

# %% [markdown]
# ### Problem statement
# Your Stakeholder is worried about changes in customer behavior and would like to understand this better. How would you approach this?
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Step 1 break the question down
# This allows you time to consider the question and demonstrates how you are approaching the problem.
# Look for dimensions and measures consider your Target and response. Does the data have a binary indicator or continouse.
# Answer these questions outloud.
#
# #### Step 1 Break the question down example
#
# Looking at this data I can see that we have sales and item quantitiy by different stores and over time. We also have this by regions.
# Customer behavior could be indicated a few ways by how much they are buying via qty, or how much they are spending via sales.
# We have member_id and could relate it through store ID to determine movement through stores to see if members are gravitating to other stores.
#
# #### Step 2 Choose the model
# What I would like to do is show the spending habits via sales over time and I will do this using a time series model. This will give
# us a quick way to see patterns and we can refine by segments to increase precision of any forecast. This will also give us insights into future
# models such as KNN or Linear regression in order to see more categories of customers.

# %% [markdown]
# - Step 1 Break the question down
# - Step 2 Articulate your algorithm choice and why
# - Step 3 Anticipate questions regarding data integrity and normalization and feature selection
# - Step 4 be prepared to answer how you would validate the model

# %% [markdown]
# ## How would you ensure that you have the right data?

# %% [markdown]
# Potentail Follow up questions from Step 2
#
#
# Why Time series Regression and not another model? I'm curious how you would implement KNN for customer behavior?
# Most likely you will be asked about what features you may use.
#
# Before answering this let's pause and review some terms. Your interviewer may interchange terms throughout the interview to test your knowledge of basic terms. Here is a quick cheatsheet.
#
# ![matrix%20vector.png](attachment:matrix%20vector.png)

# %% [markdown]
# Another important tip during this phase of the interview is to not freeze if you picked a model like Logistic regression and then later had second thoughts. You can always catch this by mentioning at anytime a different model that you are now realizing you would like to use. Data Science is about iteration and discovery. However,
# they may want you to stick to the original model just to see where you would go with it.

# %% [markdown]
# Now back to the question.
#
#
# Which features would you use is a trick question. They are asking; do you know about Feature Selection vs Feature Extraction. Are you aware of testing your sample or population data for its efficacy in predictions.
#
# The first step with feature extraction or selection is ensuring that the dataset you are using has been tested for efficacy and depending on what type of analysis you are doing will determing the type of tests and additional cleaning you may do.
#
#
# - Homework question which test or tests below would you use for Time series?
# - How would you evaluate good vs bad output from the test and what actions would you take?

# %% [markdown]
# ### Normality tests is the data normally distributed?
# - **The Shapiro–Wilk test** is more appropriate method for small sample sizes (<50 samples) although
#  it can also be handling on larger sample size while Kolmogorov–Smirnov test is used for n ≥50
#
# - **The D'Agostino-Pearson** is not the most powerful test, but you may use it for any distribution.
# For a normality test, if the data doesn't have repeated values we recommend using the Shapiro-Wilk test.
# If the data contains repeated values we recommend using the D'Agostino-Pearson test.
#
# - **Example of the Anderson-Darling Normality Test** The Anderson-Darling test (Stephens, 1974)
# is used to test if a sample of data came from a population with a specific distribution. It is a modification of the Kolmogorov-Smirnov (K-S) test and gives more weight to the tails than does the K-S test.
#
# ### Correlation Tests how closely are sample related?
# - **Example of the Pearson's Correlation test**
# You should use the Pearson correlation coefficient when (1) the relationship is linear and
# (2) both variables are quantitative and (3) normally distributed and (4) have no outliers.
#
# - **Example of the Spearman's Rank Correlation Test**
#  Use Spearman rank correlation when you have two ranked variables, and you want to see whether
#  the two variables covary; whether, as one variable increases, the other variable tends to increase or decrease.
#
# - **Kendall rank correlation** (non-parametric) is an alternative to Pearson's correlation (parametric)
# when the data you're working with has failed one or more assumptions of the test. This is also the best alternative to Spearman correlation (non-parametric) when your sample size is small and has many tied ranks.
#
# - **Chi Squared** used to examine whether the observed results are in order with the expected values.
# When the data to be analysed is from a random sample, and when the variable is the question is a categorical variable, then Chi-Square proves the most appropriate test for the same.
#
# ### Stationary Tests Do samples change overtime?
# - **Augmented Dickey Fuller test ( ADF Test)** is a common statistical test used to test whether a given Time series
# is stationary or not . It is one of the most commonly used statistical test when it comes to analyzing the stationary of a series. Consider weather data where there is a steady pattern of whether and then an unpredicted event occurs such as a once in ever 15 year record breaking heat wave. In that story which do you think would be stationary and non-stationary data points?
# - **Kwiatkowski–Phillips–Schmidt–Shin (KPSS)** In econometrics, Kwiatkowski–Phillips–Schmidt–Shin (KPSS) tests are used for testing a null hypothesis that an observable time series is stationary around a deterministic trend (i.e. trend-stationary) against the alternative of a unit root.
#
# ### Parametric Statistical Hypothesis Tests Are the samples means significantly different?
# - **t-test** A t-test may be used to evaluate whether a single group differs from a known value (a one-sample t-test),
# whether two groups differ from each other (an independent two-sample t-test), or whether there is a significant difference in paired measurements (a paired, or dependent samples t-test).
# - **Anova** use ANOVA when you want to test a particular hypothesis between groups, determining – in using one-way
# ANOVA – the relationship between an independent variable and one quantitative dependent variable. An example could be examining how the level of employee training impacts customer satisfaction ratings.
#
# ### Nonparametric Statisitical Hypothesis Tests Are samples equal or not?
# - **Mann-Whitney U Test**The Mann-Whitney U test is used to compare differences between two independent groups when the dependent variable is either ordinal or continuous, but not normally distributed.
#
# - **Wilcoxon Signed-Rank Test** Wilcoxon rank-sum test is used to compare two independent samples, while Wilcoxon
# signed-rank test is used to compare two related samples, matched samples, or to conduct a paired difference test of repeated measurements on a single sample to assess whether their population mean ranks differ.
# - **Kruskal-Wallis H test** The Kruskal-Wallis test is a nonparametric (distribution free) test, and is used when the
# assumptions of one-way ANOVA are not met. Both the Kruskal-Wallis test and one-way ANOVA assess for significant differences on a continuous dependent variable by a categorical independent variable (with two or more groups).
# - **Friedman Test** used to test for differences between groups when the dependent variable being measured is ordinal.
# It can also be used for continuous data that has violated the assumptions necessary to run the one-way ANOVA with repeated measures (e.g., data that has marked deviations from normality)

# %% [markdown]
# Now that we have answered the first part of the feature question we are ready to answer the second part.
#
# You can start by answering a feature extraction technique and then share the technique you would use for feature selection.
#
# be careful in feature extraction as PCA is not a great one for time series but rather something like
# Cross Correlation would be a better choice.
#
# For feature selection a great answer is to talk with domain experts for inside knowledge and to suppliment that with correlation matrix.
#
# It is important to note the questions of distrubtion and ensuring your samples are good for a model this is referring to
#
# Be prepared to offer up what results you are looking for.
# ie I would run a correlation matrix and look for anything over .6 or below -.6 as potentially signicant indicators of predictions.
#
# You could also offer creating feature matrix by using domain knowledge and higher correlation scores to boost the score.
#
# One thing to note is if they have not asked you about the tests for efficacy in your numbers this is a time they may ask.
#
# ##### What do you think the the answer is to this question; "Ok so you are going to create a feature matrix, how will you make sure that your features and response are independent of eachother?"

# %% [markdown]
# # How would you validate your targets accuracy?

# %% [markdown]
# - Arima comes with a summary
# ![image.png](attachment:image.png)
#
# - Beyond this you could alse use
#
# MAPE, WAPE, and WMAPE
# Mean Absolute Percentage Error and it measures the percentage error of the forecast in relation to the actual values.
#
# WAPE, also referred to as the MAD/Mean ratio, means Weighted Average Percentage Error. It weights the error by adding the total
#
# neither MAPE nor WAPE take into account possible differences in priority between products or moments in time. In our example, let’s say we find Monday the most important day to predict. How can we reflect this in our prediction error?
#
# WMAPE can be used when the use case requires this. It means Weighted Mean Absolute Percentage Error and is calculated as follows:

# %% [markdown]
# # What might you do to tune your model

# %% [markdown]
# ![Untitled.webp](attachment:Untitled.webp)

# %% [markdown]
# You can do several things to tune your model;
# adjusting your PDQ scores, Adjusting DIFF, reviewing features used. Creating segments of data, exploring domain knowledge to find events that should be  removed for normilization.
